# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from optpy import *

# %%
info = {
    "name": "GRB221009A",
    "ra":288.265,
    "dec": 19.774,
    "emin": 100,
    "emax": 1e4,
    "trigger": 687014224.99,
}

optical_data = glob("./*.dat")

# %%
table = read_data(optical_data, t_shift = info["trigger"], flux_units="Jy", time_units="second", energy_units="Hz")

# %%
table
# Out:
# <Table length=32>
# filter         date-obs        ...        eV_err                eV
#                                ...          eV                  eV
#  str2           str23          ...       float64             float64
# ------ ----------------------- ... -------------------- ------------------
#      i 2022-10-11T00:03:39.927 ...  0.12298307973623768  1.652455053934214
#      i 2022-10-12T00:21:05.280 ...  0.12298307973623768  1.652455053934214
#      i 2022-10-14T00:45:34.080 ...  0.12298307973623768  1.652455053934214
#      R 2022-10-10T04:22:04.800 ...  0.15860334738438997 1.9028881301925575
#      R 2022-10-11T03:39:21.600 ...  0.15860334738438997 1.9028881301925575
#      B 2022-10-10T04:18:54.720 ...  0.28441494715898896 2.8828037079719744
#    ...                     ... ...                  ...                ...
#      J              2022-10-18 ... 0.061946077466917715 1.0039206350866416
#     Ks              2022-10-18 ... 0.032837710838609535 0.5742667829235769
# ...

# %%
plot_lightcurve(table)
# Out:
# <Table length=4>
# filter          m          ...        m_err               k_err
# str32         str32        ...        str32               str32
# ------ ------------------- ... ------------------- -------------------
#      I  -1.633180927748473 ...  0.0403031980753102 0.20612040356760578
#     Ks -1.8295721658282618 ...  0.2289110322284735  1.3536172611204882
#      y -1.4767333997479024 ... 0.06195944064392453 0.30573492528285073
#      z -1.3357908714697924 ... 0.03504711213456397 0.17703836580414883

# %%
plot_spectrum(table)
# Out:
# <Table length=2>
#   time           m          ...        k_err               pivot
# float64       float64       ...       float64             float64
# ------- ------------------- ... -------------------- -----------------
#     0.6 -0.6971570022386405 ...  0.02343998855022708 466231964965486.9
#     1.6 -0.6982431429351981 ... 0.017004672605833937 378792296417164.5
